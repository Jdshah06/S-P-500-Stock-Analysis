# %%
import pandas as pd
import scipy as stats
from datetime import datetime

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
individual_data= "Dow Data/DOW Data.csv"
individual_industry= 'Dow Data/DOW Names.csv'
dow= "Dow Data/^DJI.csv"

# %%
individual_df = pd.read_csv(individual_data)
industry_df= pd.read_csv(individual_industry)
dow_df=pd.read_csv(dow)

# %%
individual_df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0        1/2/15  111.389999  111.440002  107.349998  109.330002  53204600
# 1        1/5/15  108.290001  108.650002  105.410004  106.250000  64285500
# 2        1/6/15  106.540001  107.430000  104.629997  106.260002  65797100
# 3        1/7/15  107.199997  108.199997  106.699997  107.750000  40105900
# 4        1/8/15  109.230003  112.150002  108.699997  111.889999  59364500
# ...         ...         ...         ...         ...         ...       ...
# 36448  12/23/19   58.709999   59.000000   58.419998   58.570000   4813200
# 36449  12/24/19   58.900002   58.919998   58.279999   58.349998   1475400
# 36450  12/26/19   58.340000   59.020000   58.299999   58.900002   2736100
# 36451  12/27/19   58.919998   59.029999   58.380001   59.020000   3647600
# 36452  12/30/19   59.090000   59.599998   58.810001   58.910000   3264500
#
#        Name
# 0      AAPL
# 1      AAPL
# 2      AAPL
# 3      AAPL
# 4      AAPL
# ...     ...
# 36448   WBA
# 36449   WBA
# 36450   WBA
# 36451   WBA
# 36452   WBA
#
# [36453 rows x 7 columns]

# %%
industry_df
# Out:
#                                      Stock Name Ticker  \
# 0                                    3M Company    MMM
# 1                      American Express Company    AXP
# 2                                    Apple Inc.   AAPL
# 3                            The Boeing Company     BA
# 4                              Caterpillar Inc.    CAT
# 5                           Chevron Corporation    CVX
# 6                           Cisco Systems, Inc.   CSCO
# 7                         The Coca-Cola Company     KO
# 8                       The Walt Disney Company    DIS
# 9                                      Dow Inc.    DOW
# 10                      Exxon Mobil Corporation    XOM
# 11                The Goldman Sachs Group, Inc.     GS
# 12                         The Home Depot, Inc.     HD
# 13  International Business Machines Corporation    IBM
# 14                            Intel Corporation   INTC
# 15                            Johnson & Johnson    JNJ
# 16                         JPMorgan Chase & Co.    JPM
# 17                       McDonald's Corporation    MCD
# 18                            Merck & Co., Inc.    MRK
# 19                        Microsoft Corporation   MSFT
# 20                                   NIKE, Inc.    NKE
# 21                                  Pfizer Inc.    PFE
# 22                 The Procter & Gamble Company     PG
# 23                The Travelers Companies, Inc.    TRV
# 24            Raytheon Technologies Corporation    RTX
# 25                                 UnitedHealth    UNH
# 26                  Verizon Communications Inc.     VZ
# 27                                    Visa Inc.      V
# 28                Walgreens Boots Alliance, Inc    WBA
# 29                                Wal-Mart Inc.    WMT
#
#                                Industry                  Sector
# 0        Specialty Industrial Machinery             Industrials
# 1                       Credit Services      Financial Services
# 2                  Consumer Electronics              Technology
# 3                   Aerospace & Defense             Industrials
# 4   Farm & Heavy Construction Machinery             Industrials
# 5                  Oil & Gas Integrated                  Energy
# 6               Communication Equipment              Technology
# 7               Beverages?Non-Alcoholic      Consumer Defensive
# 8                         Entertainment  Communication Services
# 9                             Chemicals         Basic Materials
# 10                 Oil & Gas Integrated                  Energy
# 11                      Capital Markets      Financial Services
# 12              Home Improvement Retail       Consumer Cyclical
# 13      Information Technology Services              Technology
# 14                       Semiconductors              Technology
# 15           Drug Manufacturers?General              Healthcare
# 16                    Banks?Diversified      Financial Services
# 17                          Restaurants       Consumer Cyclical
# 18           Drug Manufacturers?General              Healthcare
# 19              Software?Infrastructure              Technology
# 20               Footwear & Accessories       Consumer Cyclical
# 21           Drug Manufacturers?General              Healthcare
# 22        Household & Personal Products      Consumer Defensive
# 23        Insurance?Property & Casualty      Financial Services
# 24                  Aerospace & Defense             Industrials
# 25                     Healthcare Plans              Healthcare
# 26                     Telecom Services  Communication Services
# 27                      Credit Services      Financial Services
# 28             Pharmaceutical Retailers              Healthcare
# 29                      Discount Stores      Consumer Defensive

# %%
industry_df.rename(columns = {'Ticker':'Symbol'}, inplace=True)

# %%
individual_df.rename(columns={'Name': "Symbol"}, inplace= True)

# %%
stocks_df=individual_df.merge(industry_df, on="Symbol")
stocks_df.head(10)
# Out:
#       Date        Open        High         Low       Close    Volume Symbol  \
# 0   1/2/15  111.389999  111.440002  107.349998  109.330002  53204600   AAPL
# 1   1/5/15  108.290001  108.650002  105.410004  106.250000  64285500   AAPL
# 2   1/6/15  106.540001  107.430000  104.629997  106.260002  65797100   AAPL
# 3   1/7/15  107.199997  108.199997  106.699997  107.750000  40105900   AAPL
# 4   1/8/15  109.230003  112.150002  108.699997  111.889999  59364500   AAPL
# 5   1/9/15  112.669998  113.250000  110.209999  112.010002  53699500   AAPL
# 6  1/12/15  112.599998  112.629997  108.800003  109.250000  49650800   AAPL
# 7  1/13/15  111.430000  112.800003  108.910004  110.220001  67091900   AAPL
# 8  1/14/15  109.040001  110.489998  108.500000  109.800003  48956600   AAPL
# 9  1/15/15  110.000000  110.059998  106.660004  106.820000  60014000   AAPL
#
#    Stock Name              Industry      Sector
# 0  Apple Inc.  Consumer Electronics  Technology
# 1  Apple Inc.  Consumer Electronics  Technology
# 2  Apple Inc.  Consumer Electronics  Technology
# 3  Apple Inc.  Consumer Electronics  Technology
# 4  Apple Inc.  Consumer Electronics  Technology
# 5  Apple Inc.  Consumer Electronics  Technology
# 6  Apple Inc.  Consumer Electronics  Technology
# 7  Apple Inc.  Consumer Electronics  Technology
# 8  Apple Inc.  Consumer Electronics  Technology
# 9  Apple Inc.  Consumer Electronics  Technology

# %%
stocks_df['Daily Change'] = stocks_df['Close'] - stocks_df['Open']
max_value=stocks_df["Daily Change"].max()
max_day_profit=stocks_df.loc[(stocks_df['Daily Change']== max_value)]
max_day_profit
# Out:
#          Date        Open        High         Low      Close    Volume Symbol  \
# 4823  3/11/19  371.269989  402.670013  365.549988  400.01001  34742200     BA
#
#               Stock Name             Industry       Sector  Daily Change
# 4823  The Boeing Company  Aerospace & Defense  Industrials     28.740021

# %%
group_by_individual = stocks_df.groupby('Symbol')
daily_max_per_stock=group_by_individual['Daily Change'].max()
stock_daily_max=pd.DataFrame({"Daily Max Per Stock": daily_max_per_stock})
stock_daily_max.head()
# Out:
#         Daily Max Per Stock
# Symbol
# AAPL               8.869995
# AXP                4.720001
# BA                28.740021
# CAT                8.339997
# CSCO               1.839996

# %%
stock_daily_max = stock_daily_max.reset_index()
stock_daily_max.loc[stock_daily_max['Symbol']=='BA']
# Out:
#   Symbol  Daily Max Per Stock
# 2     BA            28.740021

# %%
stock_daily_max.sort_values('Daily Max Per Stock', ascending=False)
# Out:
#    Symbol  Daily Max Per Stock
# 2      BA            28.740021
# 7      GS            14.490005
# 23    UNH            13.290009
# 8      HD            12.419998
# 6     DIS            10.139999
# 0    AAPL             8.869995
# 3     CAT             8.339997
# 15    MMM             7.739991
# 24      V             7.209999
# 9     IBM             7.130005
# 14    MCD             6.829987
# 16    MRK             6.020001
# 5     CVX             5.980003
# 26    WBA             5.960007
# 17   MSFT             5.419999
# 12    JPM             5.260003
# 22    TRV             5.050003
# 1     AXP             4.720001
# 27    WMT             4.500000
# 18    NKE             4.310005
# 11    JNJ             3.919998
# 21    RTX             3.555694
# 28    XOM             3.440003
# 20     PG             2.669998
# 10   INTC             2.270000
# 4    CSCO             1.839996
# 19    PFE             1.720001
# 25     VZ             1.700001
# 13     KO             1.400002

# %%
min_value= stocks_df["Daily Change"].min()
max_loss_profit=stocks_df.loc[(stocks_df['Daily Change']== min_value)]
max_loss_profit
# Out:
#           Date   Open        High    Low  Close    Volume Symbol  \
# 4978  10/18/19  369.0  369.350006  344.0  344.0  13544300     BA
#
#               Stock Name             Industry       Sector  Daily Change
# 4978  The Boeing Company  Aerospace & Defense  Industrials         -25.0

# %%
stocks_df['Date']= pd.to_datetime(stocks_df['Date'])
stocks_df['Week Number']= stocks_df['Date'].dt.week
stocks_df['Year']= stocks_df['Date'].dt.year
stocks_df['Quarter']= stocks_df['Date'].dt.quarter
stocks_df
weekly_change= stocks_df.groupby(['Symbol','Year','Week Number']).agg({'Open':'first','Close':'last'})

# %%
weekly_change
# Out:
#                                Open       Close
# Symbol Year Week Number
# AAPL   2015 1            111.389999  109.330002
#             2            108.290001  112.010002
#             3            112.599998  105.989998
#             4            107.839996  112.980003
#             5            113.739998  117.160004
# ...                             ...         ...
# XOM    2019 48            69.370003   68.129997
#             49            68.500000   69.510002
#             50            69.080002   69.230003
#             51            69.699997   69.940002
#             52            69.860001   69.889999
#
# [7569 rows x 2 columns]

# %%
weekly_change=weekly_change.reset_index()

weekly_change['Weekly Change'] = weekly_change['Close'] - weekly_change['Open']

weekly_change
# Out:
#      Symbol  Year  Week Number        Open       Close  Weekly Change
# 0      AAPL  2015            1  111.389999  109.330002      -2.059997
# 1      AAPL  2015            2  108.290001  112.010002       3.720001
# 2      AAPL  2015            3  112.599998  105.989998      -6.610000
# 3      AAPL  2015            4  107.839996  112.980003       5.140007
# 4      AAPL  2015            5  113.739998  117.160004       3.420006
# ...     ...   ...          ...         ...         ...            ...
# 7564    XOM  2019           48   69.370003   68.129997      -1.240006
# 7565    XOM  2019           49   68.500000   69.510002       1.010002
# 7566    XOM  2019           50   69.080002   69.230003       0.150001
# 7567    XOM  2019           51   69.699997   69.940002       0.240005
# 12538                 Oil & Gas Integrated                  Energy
# 13795                      Capital Markets      Financial Services
# 15052              Home Improvement Retail       Consumer Cyclical
# 16309      Information Technology Services              Technology
# 17566                       Semiconductors              Technology
# 18823           Drug Manufacturers?General              Healthcare
# 20080                    Banks?Diversified      Financial Services
# 21337                          Restaurants       Consumer Cyclical
# 22594           Drug Manufacturers?General              Healthcare
# 23851              Software?Infrastructure              Technology
# 25108               Footwear & Accessories       Consumer Cyclical
# 26365           Drug Manufacturers?General              Healthcare
# 27622        Household & Personal Products      Consumer Defensive
# 28879        Insurance?Property & Casualty      Financial Services
# 30136                  Aerospace & Defense             Industrials
# 31393                     Healthcare Plans              Healthcare
# 32650                     Telecom Services  Communication Services
# 33907                      Credit Services      Financial Services
# 35164                      Discount Stores      Consumer Defensive
# 36421             Pharmaceutical Retailers              Healthcare
#
#        Daily Change  Week Number  Year  Quarter
# 1225       3.339996           46  2019        4
# 2482       0.440002           46  2019        4
# 3739      -0.009995           46  2019        4
# 4996       0.630005           46  2019        4
# 6253       0.130004           46  2019        4
# 7510       1.820000           46  2019        4
# 8767       0.219997           46  2019        4
# 10024      0.230000           46  2019        4
# 11281     10.139999           46  2019        4
# 12538     -0.219994           46  2019        4
# 13795      0.930008           46  2019        4
# 15052      2.710007           46  2019        4
# 16309     -0.910003           46  2019        4
# 17566      0.020000           46  2019        4
# 18823      0.230011           46  2019        4
# 20080      0.349991           46  2019        4
# 21337      1.229996           46  2019        4
# 22594      0.269997           46  2019        4
# 23851      0.569993           46  2019        4
# 25108      1.559998           46  2019        4
# 26365     -0.350003           46  2019        4
# 27622      0.750000           46  2019        4
# 28879      1.430008           46  2019        4
# 30136      0.270615           46  2019        4
# 31393     -1.299988           46  2019        4
# 32650      0.259998           46  2019        4
# 33907      0.010010           46  2019        4
# 35164      1.819999           46  2019        4
# 36421     -0.380001           46  2019        4

# %%
week_high_2015= weekly_change.loc[(weekly_change['Week Number']== 10) & (weekly_change['Year']== 2015)]

# %%
week_high_2015_max= week_high_2015['Weekly Change'].max()
week_high_2015_max_stock= weekly_change.loc[weekly_change['Weekly Change']== week_high_2015_max]
week_high_2015_max_stock
# Out:
#     Symbol  Year  Week Number        Open       Close  Weekly Change
# 531     BA  2015           10  150.850006  153.119995       2.269989

# %%
week_high_2016= weekly_change.loc[(weekly_change['Week Number']== 34) & (weekly_change['Year']== 2016)]
week_high_2016_max= week_high_2016['Weekly Change'].max()
week_high_2016_max_stock= weekly_change.loc[weekly_change['Weekly Change']== week_high_2016_max]
week_high_2016_max_stock
# Out:
#      Symbol  Year  Week Number       Open  Close  Weekly Change
# 1130   CSCO  2016           34  30.440001  31.35       0.909999

# %%
week_high_2017= weekly_change.loc[(weekly_change['Week Number']== 23) & (weekly_change['Year']== 2017)]
week_high_2017_max= week_high_2017['Weekly Change'].max()
week_high_2017_max_stock= weekly_change.loc[weekly_change['Weekly Change']== week_high_2017_max]
week_high_2017_max_stock
# Out:
#      Symbol  Year  Week Number        Open       Close  Weekly Change
# 1954     GS  2017           23  213.080002  222.440002           9.36

# %%
week_high_2018= weekly_change.loc[(weekly_change['Week Number']== 38) & (weekly_change['Year']== 2018)]
week_high_2018_max= week_high_2018['Weekly Change'].max()
week_high_2018_max_stock= weekly_change.loc[weekly_change['Weekly Change']== week_high_2018_max]
week_high_2018_max_stock
# Out:
#     Symbol  Year  Week Number        Open       Close  Weekly Change
# 716     BA  2018           38  359.279999  372.230011      12.950012

# %%
week_high_2019= weekly_change.loc[(weekly_change['Week Number']== 46) & (weekly_change['Year']== 2019)]
week_high_2019_max= week_high_2019['Weekly Change'].max()
week_high_2019_max_stock= weekly_change.loc[weekly_change['Weekly Change']== week_high_2019_max]
week_high_2019_max_stock
# Out:
#     Symbol  Year  Week Number        Open       Close  Weekly Change
# 776     BA  2019           46  349.040009  371.679993      22.639984

# %%
stocks_df['Date']= pd.to_datetime(stocks_df['Date'])
stocks_df['Month Number']= stocks_df['Date'].dt.month
stocks_df
monthly_change_old= stocks_df.groupby(['Symbol','Year','Month Number','Sector']).agg({'Open':'first','Close':'last'})

# %%
monthly_change=monthly_change_old.reset_index()

# %%
monthly_change
# Out:
#      Symbol  Year  Month Number      Sector        Open       Close
# 0      AAPL  2015             1  Technology  111.389999  117.160004
# 1      AAPL  2015             2  Technology  118.050003  128.460007
# 2      AAPL  2015             3  Technology  129.250000  124.430000
# 3      AAPL  2015             4  Technology  124.820000  125.150002
# 4      AAPL  2015             5  Technology  126.099998  130.279999
# ...     ...   ...           ...         ...         ...         ...
# 1735    XOM  2019             8      Energy   73.739998   68.480003
# 1736    XOM  2019             9      Energy   67.889999   70.610001
# 1737    XOM  2019            10      Energy   70.830002   67.570000
# 1738    XOM  2019            11      Energy   68.389999   68.129997
# 1739    XOM  2019            12      Energy   68.500000   69.480003
#
# [1740 rows x 6 columns]

# %%
monthly_change["Monthly Change"]= monthly_change['Close'] - monthly_change['Open']

# %%
monthly_change_group=monthly_change.groupby(["Sector","Year","Month Number"])["Monthly Change"].mean()

# %%
stocks_month = pd.DataFrame(monthly_change_group)
#stocks_month = stocks_month.unstack(level=0)
stocks_month = stocks_month.reset_index()
#df.YEAR.astype(str) + '/' + df.MONTH.astype(str)

#stocks_month['Year-Month'] = stocks_month['Year'].astype(str) + "-" + stocks_month['Month_number'].astype(str)
year_month_df=pd.DataFrame({'year': stocks_month['Year'], 'month': stocks_month['Month Number'], 'day':[1 for x in range(480)]})
stocks_month['Year-Month']= pd.to_datetime(year_month_df)
stocks_month
# Out:
#                      Sector  Year  Month Number  Monthly Change Year-Month
# 0    Communication Services  2015             1       -2.620003 2015-01-01
# 1    Communication Services  2015             2        8.015000 2015-02-01
# 2    Communication Services  2015             3        0.025002 2015-03-01
# 3    Communication Services  2015             4        2.639999 2015-04-01
# 4    Communication Services  2015             5       -0.444997 2015-05-01
# ..                      ...   ...           ...             ...        ...
# 475              Technology  2019             8       -5.961996 2019-08-01
# 476              Technology  2019             9        7.543999 2019-09-01
# 477              Technology  2019            10        3.591995 2019-10-01
# 478              Technology  2019            11        5.070003 2019-11-01
# 479              Technology  2019            12        6.360000 2019-12-01
#
# [480 rows x 5 columns]

# %%
month_list= stocks_month['Year-Month'].tolist()
calender=['January 2015','February','March','April','May','June','July','August','September','October','November','December',
         'January 2016','February','March','April','May','June','July','August','September','October','November','December',
         'January 2017','February','March','April','May','June','July','August','September','October','November','December',
         'January 2018','February','March','April','May','June','July','August','September','October','November','December',
         'January 2019','February','March','April','May','June','July','August','September','October','November','December']

# %%
stocks_month.head()
stocks_month=stocks_month.groupby(['Sector','Year-Month'])['Monthly Change'].mean()

stocks_b = pd.DataFrame(stocks_month)
stocks_b =stocks_b.unstack(level=0)
stocks_b.columns = stocks_b.columns.droplevel()
stocks_b = stocks_b.reset_index()
stocks_b.set_index("Year-Month",inplace= True)
stocks_b

fig = plt.figure(figsize = (20,10))
ax1 = fig.add_subplot(2,1,1)
#ax2 = fig.add_subplot(2,1,2)

stocks_b.plot(ax=ax1)
#ax2.plot(x_axis, s_p_df['Close'], label="S&P 500")

ax1.set_title('Monthly Change')
ax1,plt.xticks(month_list,calender,rotation=90)
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))

ax1.grid()
#ax2.grid()
#plt.tight_layout()

# %%
fig = plt.figure(figsize=(20,7))
plt.plot(stocks_b['Energy'])
plt.xticks(month_list,calender,rotation=90)
plt.grid()
plt.show()

# %%
quarterly_change= stocks_df.groupby(['Symbol','Year','Quarter','Sector']).agg({'Open':'first','Close':'last'})
quarterly_change['Quarterly Change'] = quarterly_change['Close'] - quarterly_change['Open']
quarterly_change
# Out:
#                                       Open       Close  Quarterly Change
# Symbol Year Quarter Sector
# AAPL   2015 1       Technology  111.389999  124.430000         13.040001
#             2       Technology  124.820000  125.430000          0.610000
#             3       Technology  126.900002  110.300003        -16.599999
#             4       Technology  109.070000  105.260002         -3.809998
#        2016 1       Technology  102.610001  108.989998          6.379997
# ...                                    ...         ...               ...
# XOM    2018 4       Energy       85.349998   68.190002        -17.159996
#        2019 1       Energy       67.349998   80.800003         13.450005
#             2       Energy       81.230003   76.629997         -4.600006
#             3       Energy       77.129997   70.610001         -6.519996
#             4       Energy       70.830002   69.480003         -1.349999
#
# [580 rows x 3 columns]

# %%
quarterly_change=quarterly_change.reset_index()
stocks_quarter=pd.DataFrame(quarterly_change)
stocks_quarter
# Out:
#     Symbol  Year  Quarter      Sector        Open       Close  \
# 0     AAPL  2015        1  Technology  111.389999  124.430000
# 1     AAPL  2015        2  Technology  124.820000  125.430000
# 2     AAPL  2015        3  Technology  126.900002  110.300003
# 3     AAPL  2015        4  Technology  109.070000  105.260002
# 4     AAPL  2016        1  Technology  102.610001  108.989998
# ..     ...   ...      ...         ...         ...         ...
# 575    XOM  2018        4      Energy   85.349998   68.190002
# 576    XOM  2019        1      Energy   67.349998   80.800003
# 577    XOM  2019        2      Energy   81.230003   76.629997
# 578    XOM  2019        3      Energy   77.129997   70.610001
# 579    XOM  2019        4      Energy   70.830002   69.480003
#
#      Quarterly Change
# 0           13.040001
# 1            0.610000
# 2          -16.599999
# 3           -3.809998
# 4            6.379997
# ..                ...
# 575        -17.159996
# 576         13.450005
# 577         -4.600006
# 578         -6.519996
# 579         -1.349999
#
# [580 rows x 7 columns]

# %%
max_value=quarterly_change["Quarterly Change"].max()
max_quarterly_change=quarterly_change.loc[(quarterly_change['Quarterly Change']== max_value)]
max_quarterly_change
# Out:
#     Symbol  Year  Quarter              Sector   Open       Close  \
# 147     GS  2016        4  Financial Services  160.5  239.449997
#
#      Quarterly Change
# 147         78.949997

# %%
stocks_quarter["Year-Quarter"]= stocks_quarter['Year'].astype(str)+ " Q: "+ stocks_quarter['Quarter'].astype(str)
quarter_list= stocks_quarter['Year-Quarter'].tolist()

# %%
quarter_list
# Out:
# ['2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4',
#  '2015 Q: 1',
#  '2015 Q: 2',
#  '2015 Q: 3',
#  '2015 Q: 4',
#  '2016 Q: 1',
#  '2016 Q: 2',
#  '2016 Q: 3',
#  '2016 Q: 4',
#  '2017 Q: 1',
#  '2017 Q: 2',
#  '2017 Q: 3',
#  '2017 Q: 4',
#  '2018 Q: 1',
#  '2018 Q: 2',
#  '2018 Q: 3',
#  '2018 Q: 4',
#  '2019 Q: 1',
#  '2019 Q: 2',
#  '2019 Q: 3',
#  '2019 Q: 4']

# %%
stocks_quarter_g= stocks_quarter.groupby(['Sector','Year-Quarter'])['Quarterly Change'].mean()
stocks_quarter_g
# Out:
# Sector                  Year-Quarter
# Communication Services  2015 Q: 1        5.804998
#                         2015 Q: 2        3.434999
#                         2015 Q: 3       -7.940001
#                         2015 Q: 4        2.420000
#                         2016 Q: 1        2.299999
#                                           ...
# Technology              2018 Q: 4      -25.392000
#                         2019 Q: 1       20.398001
#                         2019 Q: 2        2.292001
#                         2019 Q: 3        5.081998
#                         2019 Q: 4       15.437994
# Name: Quarterly Change, Length: 160, dtype: float64

# %%
stocks_quarter_graph_index= pd.DataFrame(stocks_quarter_g)
stocks_quarter_graph=stocks_quarter_graph_index.reset_index()
stocks_quarter_graph
stocks_quarter_graph.set_index("Year-Quarter", inplace= True)

# %%
stocks_quarter_graph
# Out:
#                               Sector  Quarterly Change
# Year-Quarter
# 2015 Q: 1     Communication Services          5.804998
# 2015 Q: 2     Communication Services          3.434999
# 2015 Q: 3     Communication Services         -7.940001
# 2015 Q: 4     Communication Services          2.420000
# 2016 Q: 1     Communication Services          2.299999
# ...                              ...               ...
# 2018 Q: 4                 Technology        -25.392000
# 2019 Q: 1                 Technology         20.398001
# 2019 Q: 2                 Technology          2.292001
# 2019 Q: 3                 Technology          5.081998
# 2019 Q: 4                 Technology         15.437994
#
# [160 rows x 2 columns]

# %%
plt.plot(stocks_quarter_graph["Quarterly Change"])

# %%
# Coorelation
dow_df.head()
# Out:
#      Date         Open         High          Low        Close     Volume
# 0  1/2/15  17823.07031  17951.77930  17731.30078  17832.99023   76270000
# 1  1/5/15  17821.30078  17821.30078  17475.92969  17501.65039  116160000
# 2  1/6/15  17504.17969  17581.05078  17262.36914  17371.64063  101870000
# 3  1/7/15  17374.77930  17597.08008  17374.77930  17584.51953   91030000
# 4  1/8/15  17591.97070  17916.03906  17591.97070  17907.86914  114890000

# %%
dow_df['Date']= pd.to_datetime(dow_df['Date'])
dow_df['Month Number']= dow_df['Date'].dt.month
dow_df['Year'] = dow_df['Date'].dt.year
dow_df
monthly_change_dow= dow_df.groupby(['Year','Month Number']).agg({'Open':'first','Close':'last'})

# %%
monthly_change_dow=monthly_change_dow.reset_index()
monthly_change_dow["Monthly Change"]= monthly_change_dow['Close']- monthly_change_dow['Open']
monthly_change_dow["Year-Month"]= pd.to_datetime(year_month_df)

# %%
monthly_change_dow
# Out:
#     Year  Month Number         Open        Close  Monthly Change Year-Month
# 0   2015             1  17823.07031  17164.94922      -658.12109 2015-01-01
# 1   2015             2  17169.99023  18132.69922       962.70899 2015-02-01
# 2   2015             3  18134.05078  17776.11914      -357.93164 2015-03-01
# 3   2015             4  17778.51953  17840.51953        62.00000 2015-04-01
# 4   2015             5  17859.26953  18010.67969       151.41016 2015-05-01
# 5   2015             6  18017.82031  17619.50977      -398.31054 2015-06-01
# 6   2015             7  17638.11914  17689.85938        51.74024 2015-07-01
# 7   2015             8  17696.74023  16528.02930     -1168.71093 2015-08-01
# 8   2015             9  16528.02930  16284.70020      -243.32910 2015-09-01
# 9   2015            10  16278.62012  17663.53906      1384.91894 2015-10-01
# 10  2015            11  17672.61914  17719.91992        47.30078 2015-11-01
# 11  2015            12  17719.72070  17425.02930      -294.69140 2015-12-01
# 12  2016             1  17405.48047  16466.30078      -939.17969 2016-01-01
# 13  2016             2  16453.63086  16516.50000        62.86914 2016-02-01
# 14  2016             3  16545.66992  17685.08984      1139.41992 2016-03-01
# 15  2016             4  17661.74023  17773.64063       111.90040 2016-04-01
# 16  2016             5  17783.77930  17787.19922         3.41992 2016-05-01
# 17  2016             6  17754.55078  17929.99023       175.43945 2016-06-01
# 18  2016             7  17924.24023  18432.24023       508.00000 2016-07-01
# 19  2016             8  18434.50000  18400.88086       -33.61914 2016-08-01
# 20  2016             9  18396.57031  18308.15039       -88.41992 2016-09-01
# 21  2016            10  18279.59961  18142.41992      -137.17969 2016-10-01
# 22  2016            11  18158.24023  19123.58008       965.33985 2016-11-01
# 23  2016            12  19149.19922  19762.59961       613.40039 2016-12-01
# 24  2017             1  19872.85938  19864.08984        -8.76954 2017-01-01
# 25  2017             2  19923.81055  20812.24023       888.42968 2017-02-01
# 26  2017             3  20957.28906  20663.22070      -294.06836 2017-03-01
# 27  2017             4  20665.16992  20940.50977       275.33985 2017-04-01
# 28  2017             5  20962.73047  21008.65039        45.91992 2017-05-01
# 29  2017             6  21030.55078  21349.63086       319.08008 2017-06-01
# 30  2017             7  21392.30078  21891.11914       498.81836 2017-07-01
# 31  2017             8  21961.41992  21948.09961       -13.32031 2017-08-01
# 32  2017             9  21981.76953  22405.08984       423.32031 2017-09-01
# 33  2017            10  22423.47070  23377.24023       953.76953 2017-10-01
# 34  2017            11  23442.90039  24272.34961       829.44922 2017-11-01
# 35  2017            12  24305.40039  24719.22070       413.82031 2017-12-01
# 2018-08-01       503.18945
# 2018-09-01       542.24024
# 2018-10-01     -1482.59961
# 2018-11-01       396.38086
# 2018-12-01     -2452.10937
# 2019-01-01      1941.06054
# 2019-02-01       890.68945
# 2019-03-01       -90.99023
# 2019-04-01       517.81055
# 2019-05-01     -1824.02149
# 2019-06-01      1769.80078
# 2019-07-01        58.41015
# 2019-08-01      -476.58008
# 2019-09-01       718.57031
# 2019-10-01        83.69141
# 2019-11-01       908.46094
# 2019-12-01       352.40040

# %%
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(dow_graph))
plt.plot(ax, dow_graph)
plt.title('Dow Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
stocks_df['Sector'].value_counts()
# Out:
# Financial Services        6285
# Healthcare                6285
# Technology                6285
# Industrials               5028
# Consumer Defensive        3771
# Consumer Cyclical         3771
# Communication Services    2514
# Energy                    2514
# Name: Sector, dtype: int64

# %%
sectors=["Technology",'Healthcare','Financial Services','Industrials',
        'Consumer Defensive','Consumer Cyclical','Communication Services',
        'Energy']
correlation_counts=[]

# %%
healthcare= stocks_b['Healthcare']
healthcare= pd.DataFrame(healthcare)
healthcare
# Out:
#             Healthcare
# Year-Month
# 2015-01-01    0.103999
# 2015-02-01    3.972000
# 2015-03-01    0.720000
# 2015-04-01   -1.955999
# 2015-05-01    2.753998
# 2015-06-01   -1.649999
# 2015-07-01    3.287999
# 2015-08-01   -6.204000
# 2015-09-01   -0.170000
# 2015-10-01    3.676000
# 2015-11-01   -1.844001
# 2015-12-01    0.832000
# 2016-01-01   -1.139999
# 2016-02-01    1.013999
# 2016-03-01    3.679998
# 2016-04-01    1.543998
# 2016-05-01    0.676000
# 2016-06-01    4.799999
# 2016-07-01    0.873998
# 2016-08-01   -1.953999
# 2016-09-01    0.109998
# 2016-10-01   -0.618000
# 2016-11-01    3.904003
# 2016-12-01    0.099999
# 2017-01-01   -0.169999
# 2017-02-01    4.792000
# 2017-03-01   -1.402000
# 2017-04-01    2.178001
# 2017-05-01    0.261998
# 2017-06-01    2.109997
# 2017-07-01    1.462003
# 2017-08-01    1.293999
# 2017-09-01   -1.787999
# 2017-10-01    0.420001
# 2017-11-01    4.890002
# 2017-12-01   -1.363999
# 2018-01-01    3.917999
# 2018-02-01   -5.527996
# 2018-03-01   -3.333999
# 2018-04-01    4.723997
# 2018-05-01   -0.858002
# 2018-06-01    0.169998
# 2018-07-01    7.318003
# 2018-08-01    4.075996
# 2018-09-01    2.210001
# 2018-10-01    0.858004
# 2018-11-01    7.805989
# 2018-12-01  -14.585999
# 2019-01-01    6.736003
# 2019-02-01   -3.804000
# 2019-03-01   -0.208003
# 2019-04-01   -6.480002
# 2019-05-01   -0.770002
# 2019-06-01    4.267996
# 2019-07-01   -2.760000
# 2019-08-01   -3.969999
# 2019-09-01   -2.141998
# 2019-10-01    7.993998
# 2019-11-01    7.155998
# 2019-12-01    4.574001

# %%
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(healthcare))
plt.plot(ax, healthcare)
plt.title('Healthcare Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
# x_ax= healthcare
# y_ax=dow_graph
# (slope, intercept, r_value, p_value, st_err) = st.linregress(x_ax,y_ax)
# fit = x_ax * slope + intercept
# plt.scatter(x_ax,y_ax)
# plt.plot(x_ax,fit,'r',lw=2)

# %%
h_count=healthcare.corrwith(dow_graph['Monthly Change'])
correlation_counts.append(h_count)

# %%
t_df= stocks_b['Technology']
technology=pd.DataFrame(t_df)
technology
# Out:
#             Technology
# Year-Month
# 2015-01-01   -2.721998
# 2015-02-01    4.984001
# 2015-03-01   -2.624000
# 2015-04-01    4.474000
# 2015-05-01    0.247999
# 2015-06-01   -4.280000
# 2015-07-01   -1.175998
# 2015-08-01   -5.799999
# 2015-09-01    1.112000
# 2015-10-01    3.908001
# 2015-11-01   -0.532001
# 2015-12-01   -2.994001
# 2016-01-01   -4.154002
# 2016-02-01    0.888000
# 2016-03-01    7.849997
# 2016-04-01   -5.517998
# 2016-05-01    3.756001
# 2016-06-01   -0.976000
# 2016-07-01    5.416000
# 2016-08-01    0.518001
# 2016-09-01    2.018000
# 2016-10-01   -0.895999
# 2016-11-01    0.967999
# 2016-12-01    2.662000
# 2017-01-01    3.097999
# 2017-02-01    3.422003
# 2017-03-01    0.180003
# 2017-04-01   -2.122005
# 2017-05-01   -0.236003
# 2017-06-01   -2.405998
# 2017-07-01    0.125997
# 2017-08-01    2.925998
# 2017-09-01   -0.910001
# 2017-10-01    7.973999
# 2017-11-01    0.844000
# 2017-12-01    0.576001
# 2018-01-01    3.995998
# 2018-02-01    1.569998
# 2018-03-01   -2.958000
# 2018-04-01   -1.001999
# 2018-05-01    5.021999
# 2018-06-01   -2.458000
# 2018-07-01    3.977996
# 2018-08-01    8.534000
# 2018-09-01    1.160004
# 2018-10-01  -11.294001
# 2018-11-01   -4.660001
# 2018-12-01  -11.642000
# 2019-01-01    9.002000
# 2019-02-01    5.579998
# 2019-03-01    4.952003
# 2019-04-01    3.522004
# 2019-05-01  -13.250000
# 2019-06-01    9.905999
# 2019-07-01    3.909999
# 2019-08-01   -5.961996
# 2019-09-01    7.543999
# 2019-10-01    3.591995
# 2019-11-01    5.070003
# 2019-12-01    6.360000

# %%
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(technology))
plt.plot(ax, technology)
plt.title('Technology Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
t_count=technology.corrwith(dow_graph['Monthly Change'])
correlation_counts.append(t_count)

# %%
f_df= stocks_b['Financial Services']
financial_services=pd.DataFrame(f_df)
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(financial_services))
plt.plot(ax, financial_services)
plt.title('Financial Services Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
f_count= financial_services.corrwith(dow_graph['Monthly Change'])
correlation_counts.append(f_count)
f_count
# Out:
# Financial Services    0.874308
# dtype: float64

# %%
i_df= stocks_b['Industrials']
industrials=pd.DataFrame(i_df)
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(industrials))
plt.plot(ax, industrials)
plt.title('Industrials Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
i_count= industrials.corrwith(dow_graph['Monthly Change'])
correlation_counts.append(i_count)
i_count
# Out:
# Industrials    0.852058
# dtype: float64

# %%
cd_df= stocks_b['Consumer Defensive']
consumer_defensive=pd.DataFrame(cd_df)
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(consumer_defensive))
plt.plot(ax, consumer_defensive)
plt.title('Consumer Defensive Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
cd_count= consumer_defensive.corrwith(dow_graph["Monthly Change"])
correlation_counts.append(cd_count)
cd_count
# Out:
# Consumer Defensive    0.435784
# dtype: float64

# %%
cc_df= stocks_b['Consumer Cyclical']
consumer_cyclical=pd.DataFrame(cc_df)
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(consumer_cyclical))
plt.plot(ax, consumer_cyclical)
plt.title('Consumer Cyclical Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
cc_count=consumer_cyclical.corrwith(dow_graph['Monthly Change'])
correlation_counts.append(cc_count)
cc_count
# Out:
# Consumer Cyclical    0.713978
# dtype: float64

# %%
cs_df= stocks_b['Communication Services']
communication_services=pd.DataFrame(cs_df)
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(communication_services))
plt.plot(ax, communication_services)
plt.title('Communication Services Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
cs_count=communication_services.corrwith(dow_graph['Monthly Change'])
correlation_counts.append(cs_count)
cs_count
# Out:
# Communication Services    0.593464
# dtype: float64

# %%
e_df= stocks_b['Energy']
energy=pd.DataFrame(e_df)
fig=plt.figure(figsize=(15,7))
ax= np.arange(len(energy))
plt.plot(ax, energy)
plt.title('Energy Monthly Change')
plt.xticks(ax,calender,rotation=90)
plt.grid()

# %%
e_count= energy.corrwith(dow_graph['Monthly Change'])
correlation_counts.append(e_count)
e_count
# Out:
# Energy    0.710945
# dtype: float64

# %%
correlation_df=pd.DataFrame(correlation_counts)

# %%
#correlation_df= correlation_df.dropna()

# %%
correlation_df
# Out:
#    Healthcare  Technology  Financial Services  Industrials  \
# 0    0.638121         NaN                 NaN          NaN
# 1         NaN    0.794922                 NaN          NaN
# 2         NaN         NaN            0.874308          NaN
# 3         NaN         NaN                 NaN     0.852058
# 4         NaN         NaN                 NaN          NaN
# 5         NaN         NaN                 NaN          NaN
# 6         NaN         NaN                 NaN          NaN
# 7         NaN         NaN                 NaN          NaN
#
#    Consumer Defensive  Consumer Cyclical  Communication Services    Energy
# 0                 NaN                NaN                     NaN       NaN
# 1                 NaN                NaN                     NaN       NaN
# 2                 NaN                NaN                     NaN       NaN
# 3                 NaN                NaN                     NaN       NaN
# 4            0.435784                NaN                     NaN       NaN
# 5                 NaN           0.713978                     NaN       NaN
# 6                 NaN                NaN                0.593464       NaN
# 7                 NaN                NaN                     NaN  0.710945
